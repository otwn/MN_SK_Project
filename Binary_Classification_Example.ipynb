# %% [markdown]
# <a href="https://colab.research.google.com/github/otwn/MN_SK_Project/blob/master/Binary_Classification_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
csv = pd.read_csv("https://raw.githubusercontent.com/otwn/MN_SK_Project/master/Bank_Personal_Loan_Modelling.csv")

# %%
csv.columns
# Out:
# Index(['ID', 'Age', 'Experience', 'Income', 'ZIP Code', 'Family', 'CCAvg',
#        'Education', 'Mortgage', 'Personal Loan', 'Securities Account',
#        'CD Account', 'Online', 'CreditCard'],
#       dtype='object')

# %%
# !pip install pycaret

# %%
import pycaret

# %%
from pycaret.classification import *
exp = setup(data = csv, target = 'Personal Loan')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_9241a438_ab7b_11ea_9042_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9241a438_ab7b_11ea_9042_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9241a438_ab7b_11ea_9042_0242ac1c0002row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_9241a438_ab7b_11ea_9042_0242ac1c0002row0_col1" class="data row0 col1" >600</td>
#             </tr>
#             <tr>
#                         <th id="T_9241a438_ab7b_11ea_9042_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9241a438_ab7b_11ea_9042_0242ac1c0002row1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_bda17f7c_ab7b_11ea_9042_0242ac1c0002 th {
#           text-align: left;
#     }    #T_bda17f7c_ab7b_11ea_9042_0242ac1c0002row0_col0 {
#             text-align:  left;
#         }    #T_bda17f7c_ab7b_11ea_9042_0242ac1c0002row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_bda17f7c_ab7b_11ea_9042_0242ac1c0002row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_bda17f7c_ab7b_11ea_9042_0242ac1c0002row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_bda17f7c_ab7b_11ea_9042_0242ac1c0002row0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_bda17f7c_ab7b_11ea_9042_0242ac1c0002row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_bda17f7c_ab7b_11ea_9042_0242ac1c0002row0_col6 {
# ...

# %%
rf = create_model('rf')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9886  0.9822  0.8788  1.0000  0.9355  0.9292
# 1       0.9829  0.9910  0.8485  0.9655  0.9032  0.8939
# 2       0.9886  0.9995  0.9697  0.9143  0.9412  0.9349
# 3       0.9857  0.9826  0.8824  0.9677  0.9231  0.9152
# 4       0.9771  0.9973  0.7941  0.9643  0.8710  0.8586
# 5       0.9743  0.9812  0.7941  0.9310  0.8571  0.8431
# 6       0.9771  0.9944  0.7941  0.9643  0.8710  0.8586
# 7       0.9800  0.9810  0.8235  0.9655  0.8889  0.8780
# 8       0.9743  0.9931  0.7941  0.9310  0.8571  0.8431
# 9       0.9799  0.9649  0.7879  1.0000  0.8814  0.8706
# Mean    0.9809  0.9867  0.8367  0.9604  0.8929  0.8825
# SD      0.0051  0.0099  0.0561  0.0267  0.0297  0.0325

# %%
tuned_rf = tune_model('rf')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9886  0.9979  0.9091  0.9677  0.9375  0.9312
# 1       0.9800  0.9939  0.7879  1.0000  0.8814  0.8706
# 2       0.9914  0.9995  0.9697  0.9412  0.9552  0.9505
# 3       0.9914  0.9964  0.9118  1.0000  0.9538  0.9491
# 4       0.9943  0.9996  0.9706  0.9706  0.9706  0.9674
# 5       0.9829  0.9915  0.8529  0.9667  0.9062  0.8969
# 6       0.9800  0.9949  0.8235  0.9655  0.8889  0.8780
# 7       0.9829  0.9921  0.8529  0.9667  0.9062  0.8969
# 8       0.9857  0.9973  0.8824  0.9677  0.9231  0.9152
# 9       0.9857  0.9968  0.8485  1.0000  0.9180  0.9102
# Mean    0.9863  0.9960  0.8809  0.9746  0.9241  0.9166
# SD      0.0047  0.0027  0.0568  0.0184  0.0282  0.0307

# %%
plot_model(tuned_rf, plot = 'auc')

# %%
evaluate_model(tuned_rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
